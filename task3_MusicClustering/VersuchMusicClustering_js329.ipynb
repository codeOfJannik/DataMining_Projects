# %% [markdown]
# # Data Mining Versuch Music Clustering
# * Autor: Prof. Dr. Johannes Maucher
# * Datum: 16.10.2015
#
# [Übersicht Ipython Notebooks im Data Mining Praktikum](Data Mining Praktikum.ipynb)
#
# # Einführung
# ## Lernziele:
# In diesem Versuch sollen Kenntnisse in folgenden Themen vermittelt werden:
#
# * Zugriff auf Musikdateien
# * Transcodierung von mp3 zu wav
# * Extraktion von Merkmalen in Musikdateien (Feature Extraction)
# * Optimierung mit dem genetischen Algorithmus
# * Selektion der aussagekräftigsten Merkmale (Feature Selection)
# * Clustering von Musikfiles (automatische Playlistgenerierung)
#
#
# ## Vor dem Versuch zu klärende Fragen
#
# ### Transcodierung von MP3 nach WAV und Merkmalsextraktion
# In diesem Versuch wird der MP3 Decoder [mpg123](http://www.mpg123.de/) eingesetzt. Installieren und testen sie diesen Decoder vor dem Versuch auf ihrem Rechner. Machen Sie sich zunächst mit dem in Kapitel [Gegebene Module zur Transcodierung und Feature Extraction](#Gegebene-Module-zur-Transcodierung-und-Feature-Extraction) aufgeführten Code vertraut. Versuchen Sie Funktion und Ablauf dieses Programms zu verstehen und beantworten Sie folgende Fragen.
#
# 1. Was versteht man unter den statistischen Größen _Mittelwert, Standardabweichung, Skewness und Kurtosis_?
# 2. Was beschreibt die Fourier-Transformierte eines zeitlich ausgedehnten Signals?
# 3. Mit welcher Samplingrate werden die WAV Dateien abgetastet?
# 4. Insgesamt werden 42 Merkmale pro Musiksequenz extrahiert. Beschreiben Sie kurz diese Merkmale

# %% [markdown]
# #### Aufgabe 1
# *verwendete Quelle zum Einlesen in Skewness: https://matheguru.com/stochastik/schiefe-linksschief-rechtsschief-symmetrisch.html<br>
#  verwendete Quelle zum Einlesen in Kurtosis: http://www.statistics4u.info/fundstat_germ/cc_kurtosis.html*
# - Der **Mittelwert** beschreibt den Durchschnittswert einer numerischen Datenmenge. Er ergibt sich aus der Summe aller Elemente der Menge, geteilt durch die Anzahl Elemente in der Menge.
# > $a = \{1, 3, 5, 6, 7, 8, 6\}$<br>
# $sum(a) = 36$<br>
# $len(a) = 7$<br>
# $Mittelwert(a) = \frac{sum(a)}{len(a)} = \frac{36}{7}\approx5.14$
#
# - Die **Standardabweichung** ist ein Maß dafür, wie weit die Elemente einer Zahlenmenge verteilt sind. Sie gibt an, wie stark die einzelnen Elemente im Durchschnitt vom Mittelwert der Menge abweichen.
# > Berechnung der Standardabweichung:<br><br>
# $variance(a) = \frac{(1-5.14)^2+(3-5.14)^2+(5-5.14)^2+(6-5.14)^2+(7-5.14)^2+(8-5.14)^2+(6-5.14)^2}{7}=\frac{34.8572}{7}=4.9796$<br>
# $sd(a) = \sqrt{variance(a)}=\sqrt{4.9796}\approx2.23$
#
# - **Skewness** (auf deutsch: Schiefe) gibt an, ob und inwieweit sich eine Verteilungsfunktion zu einer seite 'neigt'. Alle symmetrischen Funktionen haben eine Skewness von 0. Jede nicht-symmetrische Funktion ist hat eine positive (linksschief - Funktion neigt sich nach rechts) oder negative (rechtsschief - Funktion neigt sich nach links) Skewness. Ist eine Funktion linksschief, ist der Median größer als der Mittelwert, ist sie rechtsschief, ist er kleiner.
#
# - Die **Kurtosis** (auf deutsch: Wölbung) gibt an, wie steil/flach eine Verteilungsfunktion im Vergleich zur Normalverteilung zuläuft. Die Normalverteilung hat eine Kurtosis von 0. Ist eine Verteilungsfunktion am Maximum spitzer als die Normalverteilung, ist die Kurtosis > 0. Ist eine Verteilungsfunktion flacher als die Normalverteilung, ist die Kurtosis < 0.
#
# #### Aufgabe 2
# *verwendete Quellen zum Einarbeiten: https://www.youtube.com/playlist?list=PLLTAHuUj-zHgvbOordkJ5jLmqcls2ZNrg*
#
# Die Fourier-Transformierte eines zeitlich ausgedehnten (kontinuierlichen) Signals ist die Funktion, die beschreibt, wie das Signal in ein kontinuierliches Frequenzspektrum zerlegt werden kann.
#
# #### Aufgabe 3
# mpg123 tastet die MP3-Datei mit einer Rate von 10kHz ab und schreibt die Daten in eine WAV-Datei (*mpg123_command* in *compute_chunk_features*). Diese WAV-Datei wird anschließend in Abschnitten von 60 Sekunden gelesen, mit 600 000 Frames pro 60 Sekunden. Das bedeutet, die WAV-Datei wird ebenfalls mit 10kHz abgetastet.

# %% [markdown]
# ### Matching der Teilsequenzen
#
# 1. Nachdem für jedes Musikstück die beiden Teilsequenzen in Form der extrahierten Merkmale vorliegen: Wie kann die Ähnlichkeit zwischen Teilsequenzen ermittelt werden?
# 2. Welche Numpy- bzw. Scipy-Module können Sie für die Bestimmung der Ähnlichkeit zwischen Teilsequenzen einsetzen?

# %% [markdown]
# #### Aufgabe 1
# Da die Merkmale aller Teilsequenzen in gleich großen Vektoren gespeichert sind, lässt sich die Ähnlichkeit zwischen Teilsequenzen einfach mithilfe der euklidischen oder Cosinus-Distanz berechnen.
# #### Aufgabe 2
# Für die Berechnung der Distanz, bzw. Ähnlichkeit zwischen Teilsequenzen, kann das Modul ***scipy.spatial*** verwendet werden. Dabei wird für die Berechnung der euklidischen Distanz zweier Teilsequenzen die Vektoren der beiden Sequenzen als Numpy-Array an die Funktion *scipy.spatia.euclidean(a, b)* übergeben.

# %% [markdown]
# ### Genetischer Algorithmus für die Merkmalsselektion
#
# 1. Beschreiben Sie die Prozesschritte im genetischen Algorithmus [Genetischer Algorithmus](https://www.hdm-stuttgart.de/~maucher/Python/FunktionenAlgorithmen/html/genAlgTSP.html)
# 2. In diesem Versuch wird davon ausgegangen, dass Merkmale dann gut sind, wenn durch sie die erste Teilsequenz eines Musikstücks durch einen ähnlichen Vektor wie die jeweils zweite Teilsequenz beschrieben wird. Wie kann mit dieser Annahme der genetische Algorithmus für die Merkmalsselektion angewandt werden. Unter Merkmalsselektion versteht man allgemein die Suche nach den $r$ besten Merkmalen aus einer Menge von insgesamt $R$ Merkmalen. In diesem Versuch werden initial $R=42$ Merkmale extrahiert, aus denen dann die besten $r<R$ Merkmale zu bestimmen sind. Überlegen Sie hierfür speziell wie die Fitnessfunktion, die Kreuzung und die Mutation zu realisieren sind.

# %% [markdown]
# #### Aufgabe 1
# Ein genetischer Algorithmus durchläuft folgende Prozessschritte:
# > 1. Erzeugung einer zufälligen Population
# 2. Berechnung der Fitnesswerte aller Individuen/Chromosomen der Popultion
# 3. Selektion zweier Elternindividuen (Selektion von Individuen mit hohem Fitnesswert ist wahrscheinlicher als Seklektion von Individuen mit geringem Fitnesswert)
# 4. Merkmale der Elternindividuen werden an zufälliger Grenze getrennt und mit Merkmalen des jeweils anderen Elternindividuums zusammengefügt
# 5. Zu einer festgelegten Wahrscheinlichkeit kann es anschließend zu Mutationen kommen. Dabei werden zufälige Merkmale des Individuums zufällig verändert.
# 6. Der Fitnesswert der entstandenen Kinderindividuen wird berechnet und mit den schlechtesten Fitnesswerten der bisherigen Population verglichen. Sind die Fitnesswerte der Kinderindividuen besser als die der Individuen mit den schlechtesten Fitnesswerten, werden sie der Population hinzugefügt und die Individuen, mit den schlechtesten Fitnesswerten, der Population entfernt.
# 7. Anschließend wiederholt sich der Ablauf ab Schritt 2, bis eine festgelegte Anzahl Iterationen erreicht wurde. Jede Iteration entspricht einer Generation des genetischen Algorithmus.
#
# #### Aufgabe 2
# **Fitnessfunktion:** Die Fitness lässt sich über den Rang jeder zweiten Teilsequenz eines Musikstücks zu ihrer ersten Teilsequenz berechnen. Dazu werden für die Merkmale eines Individuums die Merkmalsvektoren aller Musikstücke gebildet und die Distanzen jedes ersten Teilstüks zu jedem zweiten Teilstück berechnet. Anschließend lässt sich aus einer nach Distanzen aufsteigend geordneten Liste bestimmen, an welchem Rang das zweite Teilstück des jeweiligen Musikstücks liegt. Diese Ränge werden aufsummiert und durch die Anzahl Musikstücke geteilt. Umso niedriger der mittlere Rang des Individuums ist, desto besser ist die Fitness des Individuums.
#
# **Kreuzung**: Für die Kreuzung werden zwei Individuen ausgewählt. Dabei ist die Auswahl von Individuen mit guter Fitness wahrscheinlicher als die Auswahl von Individuen mit schlechter Fitness. Anschließend wird eine zufällige Grenze festgelegt, an der die ausgewählten Individuen geteilt werden. Dann werden die Teilstück so zusammengefügt, dass Kopf-A und Ende-B, sowie Kopf-B und Ende-A die Kinder bilden. Es muss allerdings noch geprüft werden, ob beide Kinder noch die festgelegte Anzahl Merkmale enthalten und keine doppelten Merkmale verloren gehen. Sollten doppelte Merkmale vorliegen, wird die komplette Kreuzung erneut durchgeführt.
#
# **Mutation**: Zu Mutationen für ein Kinderindividuum kommt es zu einer geringen Wahrscheinlichkeit. Tritt eine Mutation ein, wird ein zufälliges Merkmal durch ein anderes, noch nicht vorhandenes Merkmal, ersetzt.

# %% [markdown]
# ### Clustering und Playlistgenerierung
#
# 1. Wie kann mit einem hierarchischen Clustering der Musikfiles eine Menge von Playlists erzeugt werden, so dass innerhalb einer Playlist möglichst ähnliche Titel zu finden sind?

# %% [markdown]
# #### Aufgabe 1
# Für das hierarchische Clustering muss die Matrix, die alle Merkmalsvektoren enthält, an die Funktion ***scipy.spatial.distance.pdist*** übergeben werden. Diese berechnet die paarweise Distanz zwischen allen Teilsequenzen. Diese gibt eine zusammengefasste Distanz-Matrix zurück. Diese Distanz-Matrix kann der Funktion ***scipy.cluster.hierarchy.linkage*** übergeben werden, die dann, je nach übergebener Methode und Distanzmetrik die Cluster berechnet.

# %% [markdown]
# # Durchführung
# ## Gegebene Module zur Transcodierung und Feature Extraction
# Mit dem in diesem Abschnitt gegebenen Code werden die im Unterverzeichnis _BandCollection_ befindlichen mp3-Files zunächst in wave decodiert. Danach werden aus den wave Dateien Audiomerkmale erhoben.
#
# Von jedem Musikstück werden zwei disjunkte Teilsequenzen erhoben und von beiden Teilsequenzen jeweils ein Merkmalsvektor gebildet. Der Grund hierfür ist: Für die später folgende Bestimmung der wichtigsten Merkmale (Merkmalsselektion mit dem genetischen Algorithmus), wird angenommen dass Merkmale dann gut sind, wenn die aus ihnen gebildeten Merkmalsvektoren für Teilsequenzen des gleichen Musikstücks nahe beieinander liegen und die Merkmalsvektoren von Teilsequenzen unterschiedlicher Musikstücke weiter voneinander entfernt sind. In der Merkmalsselektion werden dann die Merkmale als relevant erachtet, für die diese Annahme zutrifft.
#
# **Aufgaben:**
#
# 1. Stellen Sie im unten gegebenen Code die Verzeichnisse für Ihre Musikdateien (aktuell Unterverzeichnis _BandCollection_) und für den Ort Ihres _mpg123_ Decoders richtig ein.
# 2. Die verwendete Musiksammlung sollte mindestens 5 verschiedene Interpreten möglichst unterschiedlicher Genres enthalten. Von jedem Interpret sollten mehrere Titel (evtl. ein ganzes Album) enthalten sein.
# 3. Führen Sie den in diesem Abschnitt gegebenen Programmcode zur Audiofeature-Extraction aus. Damit werden für alle Musiksequenzen jeweils 42 Merkmale extrahiert. Die extrahierten Merkmalsvektoren der jeweils ersten Sequenz werden in das File _FeatureFileTrainingAllList1.csv_ geschrieben, die der zweiten Teilsequen in das File _FeatureFileTestAllList2.csv_.

# %%
import subprocess
import wave
import struct
import numpy as np
import os
import pandas as pd

np.set_printoptions(precision=2,suppress=True)

#Names of features extracted in this module
FeatNames=["amp1mean","amp1std","amp1skew","amp1kurt","amp1dmean","amp1dstd","amp1dskew","amp1dkurt","amp10mean","amp10std",
           "amp10skew","amp10kurt","amp10dmean","amp10dstd","amp10dskew","amp10dkurt","amp100mean","amp100std","amp100skew",
           "amp100kurt","amp100dmean","amp100dstd","amp100dskew","amp100dkurt","amp1000mean","amp1000std","amp1000skew",
           "amp1000kurt","amp1000dmean","amp1000dstd","amp1000dskew","amp1000dkurt","power1","power2","power3","power4",
           "power5","power6","power7","power8","power9","power10"]

# %%
def moments(x):
    mean = x.mean()
    std = x.var()**0.5
    skewness = ((x - mean)**3).mean() / std**3
    kurtosis = ((x - mean)**4).mean() / std**4
    return [mean, std, skewness, kurtosis]

# %%
#Feature category 2: Frequency domain parameters
def fftfeatures(wavdata):
    f = np.fft.fft(wavdata)
    f = f[2:(int(f.size / 2) + 1)]
    f = abs(f)
    total_power = f.sum()
    f = np.array_split(f, 10)
    return [e.sum() / total_power for e in f]

# %%
#Creating the entire feature vector per music-file
def features(x):
    x = np.array(x)
    f = []

    xs = x
    diff = xs[1:] - xs[:-1]
    f.extend(moments(xs))
    f.extend(moments(diff))

    xs = x.reshape(-1, 10).mean(1)
    diff = xs[1:] - xs[:-1]
    f.extend(moments(xs))
    f.extend(moments(diff))

    xs = x.reshape(-1, 100).mean(1)
    diff = xs[1:] - xs[:-1]
    f.extend(moments(xs))
    f.extend(moments(diff))

    xs = x.reshape(-1, 1000).mean(1)
    diff = xs[1:] - xs[:-1]
    f.extend(moments(xs))
    f.extend(moments(diff))

    f.extend(fftfeatures(x))
    return f

# %%
def read_wav(wav_file):
    """Returns two chunks of sound data from wave file."""
    w = wave.open(wav_file)
    n = 60 * 10000
    if w.getnframes() < n * 3:
        raise ValueError('Wave file too short')
    #For each music file 2 sequences, each containing n frames are subtracted. The first sequence starts at postion n,
    #the second sequence starts at postion 2n. The reason for extracting 2 subsequences is, that later on we like to
    #find the best features and in this exercise we assume that good features have the property that they are similar for 2 subsequences
    #of the same song, but differ for subsequences of different songs.
    w.setpos(n)
    frames = w.readframes(n)
    wav_data1 = struct.unpack('%dh' % n, frames)
    frames = w.readframes(n)
    wav_data2 = struct.unpack('%dh' % n, frames)
    return wav_data1, wav_data2

# %%
def compute_chunk_features(mp3_file):
    """Return feature vectors for two chunks of an MP3 file."""
    # Extract MP3 file to a mono, 10kHz WAV file
    #mpg123_command = 'C:\Program Files (x86)\mpg123-1.22.0-x86\mpg123-1.22.0-x86\\mpg123.exe -w "%s" -r 10000 -m "%s"'
    #mpg123_command = 'C:\\Program Files (x86)\\mpg123-1.21.0-x86-64\\mpg123.exe -w "%s" -r 10000 -m "%s"'
    #mpg123_command = 'C:\Users\maucher\Downloads\mpg123-1.23.8-x86-64\mpg123-1.23.8-x86-64\\mpg123.exe -w "%s" -r 10000 -m "%s"'
    mpg123_command = '/usr/local/Cellar/mpg123/1.25.10/bin/mpg123 -w "%s" -r 10000 -m "%s"'
    out_file = 'temp.wav'
    cmd = mpg123_command % (out_file, mp3_file)
    temp = subprocess.call(cmd, shell=True)
    # Read in chunks of data from WAV file
    wav_data1, wav_data2 = read_wav(out_file)
    # We'll cover how the features are computed in the next section!
    return np.array(features(wav_data1)), np.array(features(wav_data2))

# %%
fileList=[]
featureList1=[]
featureList2=[]
#Specify the name of the directory, which contains your MP3 files here.
# This directory should contain for each band/author one subdirectory, which contains all songs of this author
for path, dirs, files in os.walk('../Resources/BandCollection'):
    #print '-'*10,dirs,files
    for f in files:
        if not f.endswith('.mp3'):
            # Skip any non-MP3 files
            continue
        mp3_file = os.path.join(path, f)
        print (mp3_file)
        # Extract the track name (i.e. the file name) plus the names
        # of the two preceding directories. This will be useful
        # later for plotting.
        tail, track = os.path.split(mp3_file)
        tail, dir1 = os.path.split(tail)
        tail, dir2 = os.path.split(tail)
        # Compute features. feature_vec1 and feature_vec2 are lists of floating
        # point numbers representing the statistical features we have extracted
        # from the raw sound data.
        try:
            feature_vec1, feature_vec2 = compute_chunk_features(mp3_file)
        except:
            print ("Error: Chunk Features failed")
            continue
        #title=str(track)
        title=str(dir1)+'\\'+str(track)
        print ('-'*20+ title +'-'*20)
        #print "       feature vector 1:",feature_vec1
        #print "       feature vector 2:",feature_vec2
        fileList.append(title)
        featureList1.append(feature_vec1)
        featureList2.append(feature_vec2)

# Write feature vecotrs of all music files to pandas data-frame
MusicFeaturesTrain=pd.DataFrame(index=fileList,data=np.array(featureList1),columns=FeatNames)
MusicFeaturesTrain.to_csv("FeatureFileTrainingAllList1.csv")

MusicFeaturesTest=pd.DataFrame(index=fileList,data=np.array(featureList2),columns=FeatNames)
MusicFeaturesTest.to_csv("FeatureFileTestAllList2.csv")
# Out:
# ../Resources/BandCollection/LanaDelRey/03 Blue Jeans (Remastered).mp3
# --------------------LanaDelRey\03 Blue Jeans (Remastered).mp3--------------------
# ../Resources/BandCollection/LanaDelRey/05 Diet Mountain Dew.mp3
# --------------------LanaDelRey\05 Diet Mountain Dew.mp3--------------------
# ../Resources/BandCollection/LanaDelRey/06 National Anthem.mp3
# --------------------LanaDelRey\06 National Anthem.mp3--------------------
# ../Resources/BandCollection/LanaDelRey/08 Radio.mp3
# --------------------LanaDelRey\08 Radio.mp3--------------------
# ../Resources/BandCollection/LanaDelRey/11 Summertime Sadness.mp3
# --------------------LanaDelRey\11 Summertime Sadness.mp3--------------------
# ../Resources/BandCollection/LanaDelRey/02 Off to the Races.mp3
# --------------------LanaDelRey\02 Off to the Races.mp3--------------------
# ../Resources/BandCollection/LanaDelRey/07 Dark Paradise.mp3
# --------------------LanaDelRey\07 Dark Paradise.mp3--------------------
# ../Resources/BandCollection/LanaDelRey/04 Video Games (Remastered).mp3
# --------------------LanaDelRey\04 Video Games (Remastered).mp3--------------------
# ../Resources/BandCollection/LanaDelRey/01 Born to Die.mp3
# --------------------LanaDelRey\01 Born to Die.mp3--------------------
# ../Resources/BandCollection/LanaDelRey/10 Million Dollar Man.mp3
# --------------------LanaDelRey\10 Million Dollar Man.mp3--------------------
# ../Resources/BandCollection/LanaDelRey/12 This Is What Makes Us Girls.mp3
# --------------------LanaDelRey\12 This Is What Makes Us Girls.mp3--------------------
# ../Resources/BandCollection/LanaDelRey/09 Carmen.mp3
# --------------------LanaDelRey\09 Carmen.mp3--------------------
# ../Resources/BandCollection/Garrett/15 Winter Lullaby.mp3
# Error: Chunk Features failed
# ../Resources/BandCollection/Garrett/13 Ain't No Sunshine.mp3
# Error: Chunk Features failed
# ../Resources/BandCollection/Garrett/16 Little Wing.mp3
# --------------------Garrett\16 Little Wing.mp3--------------------
# ../Resources/BandCollection/Garrett/06 Brahms Hungarian Dance No. 5 1.mp3
# Error: Chunk Features failed
# ../Resources/BandCollection/Garrett/07 Chelsea Girl 1.mp3
# Error: Chunk Features failed
# ../Resources/BandCollection/Garrett/10 Air.mp3
# --------------------Garrett\10 Air.mp3--------------------
# ../Resources/BandCollection/Garrett/08 Summer 1.mp3
# Error: Chunk Features failed
# ../Resources/BandCollection/Garrett/04 He's a Pirate (Pirates of the Car 1.mp3
# --------------------Garrett\04 He's a Pirate (Pirates of the Car 1.mp3--------------------
# ../Resources/BandCollection/Garrett/11 Thunderstruck.mp3
mp3--------------------
# ../Resources/BandCollection/BeastieBoys/07 An Open Letter to NYC.mp3
# --------------------BeastieBoys\07 An Open Letter to NYC.mp3--------------------
# ../Resources/BandCollection/BeastieBoys/08 Root Down.mp3
# --------------------BeastieBoys\08 Root Down.mp3--------------------
# ../Resources/BandCollection/BeastieBoys/14 Sabotage.mp3
# Error: Chunk Features failed
# ../Resources/BandCollection/BeastieBoys/12 Body Movin' (Fatboy Slim Remix).mp3
# --------------------BeastieBoys\12 Body Movin' (Fatboy Slim Remix).mp3--------------------
# ../Resources/BandCollection/BeastieBoys/05 Hey Ladies.mp3
# --------------------BeastieBoys\05 Hey Ladies.mp3--------------------
# ../Resources/BandCollection/BeastieBoys/11 Sure Shot.mp3
# --------------------BeastieBoys\11 Sure Shot.mp3--------------------
# ../Resources/BandCollection/BeastieBoys/01 So What'cha Want.mp3
# --------------------BeastieBoys\01 So What'cha Want.mp3--------------------
# ../Resources/BandCollection/BeastieBoys/02 Brass Monkey.mp3
# Error: Chunk Features failed
# ../Resources/BandCollection/Adele/12 Lovesong.mp3
# --------------------Adele\12 Lovesong.mp3--------------------
# ../Resources/BandCollection/Adele/17 Rolling In The Deep.mp3
# --------------------Adele\17 Rolling In The Deep.mp3--------------------
# ../Resources/BandCollection/Adele/02 I'll Be Waiting.mp3
# --------------------Adele\02 I'll Be Waiting.mp3--------------------
# ../Resources/BandCollection/Adele/13 Chasing Pavements.mp3
# --------------------Adele\13 Chasing Pavements.mp3--------------------
# ../Resources/BandCollection/Adele/06 If It Hadn't Been For Love.mp3
# --------------------Adele\06 If It Hadn't Been For Love.mp3--------------------
# ../Resources/BandCollection/Adele/11 One And Only.mp3
# --------------------Adele\11 One And Only.mp3--------------------
# ../Resources/BandCollection/Adele/04 Turning Tables.mp3
# --------------------Adele\04 Turning Tables.mp3--------------------
# ../Resources/BandCollection/Adele/07 My Same.mp3
# Error: Chunk Features failed
# ../Resources/BandCollection/Adele/10 Right As Rain.mp3
# Error: Chunk Features failed
# ../Resources/BandCollection/Adele/08 Take It All.mp3
# --------------------Adele\08 Take It All.mp3--------------------
# ../Resources/BandCollection/Adele/15 Make You Feel My Love.mp3
# --------------------Adele\15 Make You Feel My Love.mp3--------------------
# ../Resources/BandCollection/Adele/14 I Can't Make You Love Me.mp3
# --------------------Adele\14 I Can't Make You Love Me.mp3--------------------
# ../Resources/BandCollection/Adele/16 Someone Like You.mp3
# --------------------Adele\16 Someone Like You.mp3--------------------
# ../Resources/BandCollection/Adele/05 Set Fire To The Rain.mp3
# --------------------Adele\05 Set Fire To The Rain.mp3--------------------
# ../Resources/BandCollection/Adele/09 Rumour Has It.mp3
# --------------------Adele\09 Rumour Has It.mp3--------------------
# ../Resources/BandCollection/Adele/01 Hometown Glory.mp3
# --------------------Adele\01 Hometown Glory.mp3--------------------
# ../Resources/BandCollection/Adele/03 Don't You Remember.mp3
# --------------------Adele\03 Don't You Remember.mp3--------------------

# %% [markdown]
# ## Matching der Teilsequenzen
# In diesem Abschnitt soll ein Verfahren implementiert werden, mit dem die Übereinstimmung der ersten Teilsequenz eines Musikstücks mit den zweiten Teilsequenzen aller anderen Musikstücke berechnet werden kann.
#
# **Aufagben:**
# 1. Lesen Sie die im vorigen Teilversuch angelegten zwei csv-Dateien in jeweils einen eigenen Pandas Dataframe ein.
# 2. Skalieren Sie beide Teilsequenzmengen, so dass alle Merkmale eine Standardabweichung von 1 aufweisen. Z.B. mit [http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.scale.html](http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.scale.html).
# 2. Bestimmen Sie zu jeder Teilsequenz aus der Datei _FeatureFileTrainingAllList1.csv_ die euklidische Distanz zu allen Teilsequenzen aus der Datei _FeatureFileTestAllList2.csv_ und schreiben Sie diese Distanzen in eine aufsteigend geordnete Liste. Schreiben Sie auch die zugehörigen Argumente (Teilsequenzen) in eine geordnete Liste, sodass für jede Teilsequenz aus _FeatureFileTrainingAllList1.csv_ die am nächsten liegende Teilsequenz aus _FeatureFileTestAllList2.csv_ an erster Stelle steht, die zweitnächste Teilsequenz an zweiter usw.
# 3. Bestimmen Sie über alle Teilsequenzen aus _FeatureFileTrainingAllList1.csv_ den **mittleren Rang** an dem die zugehörige zweite Teilsequenz erscheint. Liegt z.B. für die erste Teilsequenz des Musikstücks A die zweite Teilsequenz nur an fünfter Stelle der geordneten nächsten Nachbarliste. Dann würde diese Teilsequenz mit dem Rang 5 in den Mittelwert einfließen.
# 4. Bestimmen Sie jetzt den mittleren Rang, für den Fall, dass _correlation_ anstelle _euclidean_ als Ähnlichkeitsmaß verwendet wird. Welches Ähnlichkeitsmaß ist für diese Anwendung zu bevorzugen?
# 5. Diskutieren Sie das Ergebnis

# %%
from sklearn import preprocessing
from scipy import spatial
from ipywidgets import FloatProgress
from IPython.display import display
import random

# %% [markdown]
# #### Aufgabe 1
# Einlesen der zwei csv-Dateien in jeweils eigene Pandas Dataframes.

# %%
trainDF = pd.read_csv("FeatureFileTrainingAllList1.csv", sep=',', index_col=0)
testDF = pd.read_csv("FeatureFileTestAllList2.csv", sep=',', index_col=0)

# %% [markdown]
# ##### Ausgabe train-Dataframe

# %%
display(trainDF)
# Out:
#                                                       amp1mean       amp1std  \
# LanaDelRey\03 Blue Jeans (Remastered).mp3             2.568683   7786.132164
# LanaDelRey\05 Diet Mountain Dew.mp3                   6.527305  10489.010423
# LanaDelRey\06 National Anthem.mp3                    -3.895280   9281.813117
# LanaDelRey\08 Radio.mp3                              -6.871208   8187.590696
# LanaDelRey\11 Summertime Sadness.mp3                  0.508798   8074.077751
# LanaDelRey\02 Off to the Races.mp3                   -0.025618   8100.552595
# LanaDelRey\07 Dark Paradise.mp3                      -6.557612   7753.279974
# LanaDelRey\04 Video Games (Remastered).mp3            2.917077   5563.624089
# LanaDelRey\01 Born to Die.mp3                        16.503028   8711.166774
# LanaDelRey\10 Million Dollar Man.mp3                  7.591345   8141.675950
# LanaDelRey\12 This Is What Makes Us Girls.mp3         1.310480   7419.345533
# LanaDelRey\09 Carmen.mp3                              4.489418   7247.546897
# Garrett\16 Little Wing.mp3                            0.598080   4456.650525
# Garrett\10 Air.mp3                                   -1.219512   6197.600121
# Garrett\04 He's a Pirate (Pirates of the Car 1.mp
\
# LanaDelRey\03 Blue Jeans (Remastered).mp3             ...     0.309061
# LanaDelRey\05 Diet Mountain Dew.mp3                   ...     0.411211
# LanaDelRey\06 National Anthem.mp3                     ...     0.319399
# LanaDelRey\08 Radio.mp3                               ...     0.345092
# LanaDelRey\11 Summertime Sadness.mp3                  ...     0.308824
# LanaDelRey\02 Off to the Races.mp3                    ...     0.347797
# LanaDelRey\07 Dark Paradise.mp3                       ...     0.338631
# LanaDelRey\04 Video Games (Remastered).mp3            ...     0.351312
# LanaDelRey\01 Born to Die.mp3                         ...     0.329846
# LanaDelRey\10 Million Dollar Man.mp3                  ...     0.308489
# LanaDelRey\12 This Is What Makes Us Girls.mp3         ...     0.333610
# LanaDelRey\09 Carmen.mp3                              ...     0.383422
# Garrett\16 Little Wing.mp3                            ...     0.224101
# Garrett\10 Air.mp3                                    ...     0.362621
# Garrett\04 He's a Pirate (Pirates of the Car 1.mp3    ...     0.329264
# Garrett\11 Thunderstruck.mp3                          ...     0.300978
# Garrett\12 New Day.mp3                                ...     0.342882
# Garrett\01 Smooth Criminal 1.mp3                      ...     0.340448
# Garrett\05 Summertime 1.mp3                           ...     0.362449
# Garrett\02 Who Wants to Live Forever_ 1.mp3           ...     0.276830
# Garrett\09 O Mio Babbino Caro 1.mp3                   ...     0.285687
# Garrett\03 Clair de Lune 1.mp3                        ...     0.217163
# Garrett\14 Rock Prelude.mp3                           ...     0.343884
# RageAgainstTheMachine\09 Township Rebellion.mp3       ...     0.312859
# RageAgainstTheMachine\07 Wake Up.mp3                  ...     0.342544
# RageAgainstTheMachine\08 Fistful of Steel.mp3         ...     0.350855
# RageAgainstTheMachine\03 Take the Power Back.mp3      ...     0.306536
# RageAgainstTheMachine\04 Settle for Nothing.mp3       ...     0.321076
# RageAgainstTheMachine\01 Bombtrack.mp3                ...     0.318734
# RageAgainstTheMachine\06 Know Your Enemy.mp3          ...     0.320062
# RageAgainstTheMachine\02 Killing In the Name.mp3      ...     0.323471
# RageAgainstTheMachine\10 Freedom.mp3                  ...     0.338639
# RageAgainstTheMachine\05 Bullet In the Head.mp3       ...     0.357168
# BeastieBoys\04 No Sleep Till Brooklyn.mp3             ...     0.294450
# BeastieBoys\15 Fight for Your Right.mp3               ...     0.300666
# BeastieBoys\03 Ch-Check It Out.mp3                    ...     0.290922
# BeastieBoys\09 Shake Your Rump.mp3                    ...     0.404238
# BeastieBoys\06 Pass the Mic.mp3                       ...     0.382705
# BeastieBoys\10 Intergalactic.mp3                      ...     0.328387
# BeastieBoys\07 An Open Letter to NYC.mp3              ...     0.361335
# BeastieBoys\08 Root Down.mp3                          ...     0.400004
# BeastieBoys\12 Body Movin' (Fatboy Slim Remix).mp3    ...     0.358087
# BeastieBoys\05 Hey Ladies.mp3                         ...     0.311386
# BeastieBoys\11 Sure Shot.mp3                          ...     0.352492
# BeastieBoys\01 So What'cha Want.mp3                   ...     0.324334
# Adele\12 Lovesong.mp3                                 ...     0.383864
# Adele\17 Rolling In The Deep.mp3                      ...     0.334385
# Adele\02 I'll Be Waiting.mp3                          ...     0.289610
# Adele\13 Chasing Pavements.mp3                        ...     0.328347
# Adele\06 If It Hadn't Been For Love.mp3               ...     0.252993
# Adele\11 One And Only.mp3                             ...     0.280483
# Garrett\04 He's a Pirate (Pirates of the Car 1.mp3    ...     0.325685
# Garrett\11 Thunderstruck.mp3                          ...     0.323092
# Garrett\12 New Day.mp3                                ...     0.291367
# Garrett\01 Smooth Criminal 1.mp3                      ...     0.337971
# Garrett\05 Summertime 1.mp3                           ...     0.325661
# Garrett\02 Who Wants to Live Forever_ 1.mp3           ...     0.312109
# Garrett\09 O Mio Babbino Caro 1.mp3                   ...     0.278920
# Garrett\03 Clair de Lune 1.mp3                        ...     0.260024
# Garrett\14 Rock Prelude.mp3                           ...     0.354317
# RageAgainstTheMachine\09 Township Rebellion.mp3       ...     0.345843
# RageAgainstTheMachine\07 Wake Up.mp3                  ...     0.323715
# RageAgainstTheMachine\08 Fistful of Steel.mp3         ...     0.355707
# RageAgainstTheMachine\03 Take the Power Back.mp3      ...     0.301840
# RageAgainstTheMachine\04 Settle for Nothing.mp3       ...     0.269121
# RageAgainstTheMachine\01 Bombtrack.mp3                ...     0.292878
# RageAgainstTheMachine\06 Know Your Enemy.mp3          ...     0.349081
# RageAgainstTheMachine\02 Killing In the Name.mp3      ...     0.314565
# RageAgainstTheMachine\10 Freedom.mp3                  ...     0.386156
# RageAgainstTheMachine\05 Bullet In the Head.mp3       ...     0.321610
# BeastieBoys\04 No Sleep Till Brooklyn.mp3             ...     0.278581
# BeastieBoys\15 Fight for Your Right.mp3               ...     0.287140
# BeastieBoys\03 Ch-Check It Out.mp3                    ...     0.298943
# BeastieBoys\09 Shake Your Rump.mp3                    ...     0.358080
# BeastieBoys\06 Pass the Mic.mp3                       ...     0.355831
# BeastieBoys\10 Intergalactic.mp3                      ...     0.357652
# BeastieBoys\07 An Open Letter to NYC.mp3              ...     0.373701
# BeastieBoys\08 Root Down.mp3                          ...     0.392518
# BeastieBoys\12 Body Movin' (Fatboy Slim Remix).mp3    ...     0.359583
# BeastieBoys\05 Hey Ladies.mp3                         ...     0.307755
# BeastieBoys\11 Sure Shot.mp3                          ...     0.365393
# BeastieBoys\01 So What'cha Want.mp3                   ...     0.325941
# Adele\12 Lovesong.mp3                                 ...     0.367248
# Adele\17 Rolling In The Deep.mp3                      ...     0.290028
# Adele\02 I'll Be Waiting.mp3                          ...     0.269738
# Adele\13 Chasing Pavements.mp3                        ...     0.313145
# Adele\06 If It Hadn't Been For Love.mp3               ...     0.281081
# Adele\11 One And Only.mp3                             ...     0.293566
# Adele\04 Turning Tables.mp3                           ...     0.204741
# Adele\08 Take It All.mp3                              ...     0.212315
# Adele\15 Make You Feel My Love.mp3                    ...     0.312942
# Adele\14 I Can't Make You Love Me.mp3                 ...     0.216881
# Adele\16 Someone Like You.mp3                         ...     0.308884
# Adele\05 Set Fire To The Rain.mp3                     ...     0.238356
# Adele\09 Rumour Has It.mp3                            ...     0.352924
# Adele\01 Hometown Glory.mp3                           ...     0.260287
# Adele\03 Don't You Remember.mp3                       ...     0.258985
#
#                                                       power2    power3  \
# LanaDelRey\03 Blue Jeans (Remastered).mp3           0.219845  0.118637
# LanaDelRey\05 Diet Mountain Dew.mp3                 0.180104  0.091672
# LanaDelRey\06 National Anthem.mp3                   0.218499  0.124323
# LanaDelRey\08 Radio.mp3                             0.192770  0.107661
# LanaDelRey\11 Summertime Sadness.mp3                0.216624  0.120253
# LanaDelRey\02 Off to the Races.mp3                  0.171683  0.106717
# LanaDelRey\07 Dark Paradise.mp3                     0.201356  0.125497
# LanaDelRey\04 Video Games (Remastered).mp3          0.222085  0.115708
# LanaDelRey\01 Born to Die.mp3                       0.226365  0.113147
# LanaDelRey\10 Million Dollar Man.mp3                0.248101  0.114963
# LanaDelRey\12 This Is What Makes Us Girls.mp3       0
# LanaDelRey\03 Blue Jeans (Remastered).mp3           0.028980
# LanaDelRey\05 Diet Mountain Dew.mp3                 0.029138
# LanaDelRey\06 National Anthem.mp3                   0.018976
# LanaDelRey\08 Radio.mp3                             0.029448
# LanaDelRey\11 Summertime Sadness.mp3                0.030934
# LanaDelRey\02 Off to the Races.mp3                  0.028649
# LanaDelRey\07 Dark Paradise.mp3                     0.035585
# LanaDelRey\04 Video Games (Remastered).mp3          0.025124
# LanaDelRey\01 Born to Die.mp3                       0.024379
# LanaDelRey\10 Million Dollar Man.mp3                0.020427
# LanaDelRey\12 This Is What Makes Us Girls.mp3       0.027599
# LanaDelRey\09 Carmen.mp3                            0.018827
# Garrett\16 Little Wing.mp3                          0.045175
# Garrett\10 Air.mp3                                  0.019116
# Garrett\04 He's a Pirate (Pirates of the Car 1.mp3  0.025397
# Garrett\11 Thunderstruck.mp3                        0.035350
# Garrett\12 New Day.mp3                              0.023485
# Garrett\01 Smooth Criminal 1.mp3                    0.032901
# Garrett\05 Summertime 1.mp3                         0.036304
# Garrett\02 Who Wants to Live Forever_ 1.mp3         0.038056
# Garrett\09 O Mio Babbino Caro 1.mp3                 0.037267
# Garrett\03 Clair de Lune 1.mp3                      0.017865
# Garrett\14 Rock Prelude.mp3                         0.041926
# RageAgainstTheMachine\09 Township Rebellion.mp3     0.035852
# RageAgainstTheMachine\07 Wake Up.mp3                0.036026
# RageAgainstTheMachine\08 Fistful of Steel.mp3       0.037211
# RageAgainstTheMachine\03 Take the Power Back.mp3    0.036535
# RageAgainstTheMachine\04 Settle for Nothing.mp3     0.035198
# RageAgainstTheMachine\01 Bombtrack.mp3              0.034970
# RageAgainstTheMachine\06 Know Your Enemy.mp3        0.036927
# RageAgainstTheMachine\02 Killing In the Name.mp3    0.046708
# RageAgainstTheMachine\10 Freedom.mp3                0.042499
# RageAgainstTheMachine\05 Bullet In the Head.mp3     0.042460
# BeastieBoys\04 No Sleep Till Brooklyn.mp3           0.047134
# BeastieBoys\15 Fight for Your Right.mp3             0.045921
# BeastieBoys\03 Ch-Check It Out.mp3                  0.042825
# BeastieBoys\09 Shake Your Rump.mp3                  0.028393
# BeastieBoys\06 Pass the Mic.mp3                     0.024377
# BeastieBoys\10 Intergalactic.mp3                    0.043303
# BeastieBoys\07 An Open Letter to NYC.mp3            0.040903
# BeastieBoys\08 Root Down.mp3                        0.027758
# BeastieBoys\12 Body Movin' (Fatboy Slim Remix).mp3  0.035155
# BeastieBoys\05 Hey Ladies.mp3                       0.029156
# BeastieBoys\11 Sure Shot.mp3                        0.032962
# BeastieBoys\01 So What'cha Want.mp3                 0.027166
# Adele\12 Lovesong.mp3                               0.029929
# Adele\17 Rolling In The Deep.mp3                    0.028342
# Adele\02 I'll Be Waiting.mp3                        0.023613
# Adele\13 Chasing Pavements.mp3                      0.028420
# Adele\06 If It Hadn't Been For Love.mp3             0.021213
# Adele\11 One And Only.mp3                           0.025092
# Adele\04 Turning Tables.mp3                         0.024158
# Adele\08 Take It All.mp3                            0.024652
# Adele\15 Make You Feel My Love.mp3                  0.022643
# Adele\14 I Can't Make You Love Me.mp3               0.020860
# Adele\16 Someone Like You.mp3                       0.019415
# Adele\05 Set Fire To The Rain.mp3                   0.024253
# Adele\09 Rumour Has It.mp3                          0.024065
# Adele\01 Hometown Glory.mp3                         0.021835
# Adele\03 Don't You Remember.mp3                     0.018293
#
# [60 rows x 42 columns]

# %% [markdown]
# #### Aufgabe 2
# Die beiden Teilsequenzmengen werden skaliert, so dass alle Merkmale eine Standardabweichung von 1 aufweisen. Die skalierten Werte werden anschließend im Pandas Dataframe wieder den Musiktiteln zugeordnet.

# %%
scaledTrainDF = preprocessing.scale(trainDF)
scaledTestDF = preprocessing.scale(testDF)

trainDF = pd.DataFrame(index=trainDF.index, columns=trainDF.columns, data=scaledTrainDF)
testDF = pd.DataFrame(index=testDF.index, columns=testDF.columns, data=scaledTestDF)

# %% [markdown]
# ##### Ausgabe skaliertes train-Dataframe

# %%
display(trainDF)
# Out:
#                                                     amp1mean   amp1std  \
# LanaDelRey\03 Blue Jeans (Remastered).mp3           0
# BeastieBoys\12 Body Movin' (Fatboy Slim Remix).mp3  -0.137456  1.015594
# BeastieBoys\05 Hey Ladies.mp3                       -4.991681  0.286951
# BeastieBoys\11 Sure Shot.mp3                        -2.187747  2.225397
# BeastieBoys\01 So What'cha Want.mp3                  0.044603  2.297425
# Adele\12 Lovesong.mp3                                0.258596 -0.459928
# Adele\17 Rolling In The Deep.mp3                     0.227744 -0.291830
# Adele\02 I'll Be Waiting.mp3                         0.180264 -0.372479
# Adele\13 Chasing Pavements.mp3                      -0.122272  0.243880
# Adele\06 If It Hadn't Been For Love.mp3              0.280348 -0.830216
# Adele\11 One And Only.mp3                            0.155441 -0.254850
# Adele\04 Turning Tables.mp3                          0.246327 -1.086144
# Adele\08 Take It All.mp3                             0.247482 -1.259589
# Adele\15 Make You Feel My Love.mp3                   0.265469 -1.246052
# Adele\14 I Can't Make You Love Me.mp3                0.267055 -1.321054
# Adele\16 Someone Like You.mp3                        0.266418 -1.249320
# Adele\05 Set Fire To The Rain.mp3                    0.206760 -0.547233
# Adele\09 Rumour Has It.mp3                           0.246957 -0.262916
# Adele\01 Hometown Glory.mp3                          0.232578 -1.095311
# Adele\03 Don't You Remember.mp3                      0.146118 -0.474315
#
#                                                       ...       power1  \
# LanaDelRey\03 Blue Jeans (Remastered).mp3             ...    -0.194968
# LanaDelRey\05 Diet Mountain Dew.mp3                   ...     2.023252
# LanaDelRey\06 National Anthem.mp3                     ...     0.029512
# LanaDelRey\08 Radio.mp3                               ...     0.587455
# LanaDelRey\11 Summertime Sadness.mp3                  ...    -0.200120
# LanaDelRey\02 Off to the Races.mp3                    ...     0.646193
# LanaDelRey\07 Dark Paradise.mp3                       ...     0.447156
# LanaDelRey\04 Video Games (Remastered).mp3            ...     0.722535
# LanaDelRey\01 Born to Die.mp3                         ...     0.256374
# LanaDelRey\10 Million Dollar Man.mp3                  ...    -0.207401
# LanaDelRey\12 This Is What Makes Us Girls.mp3         ...     0.338109
# LanaDelRey\09 Carmen.mp3                              ...     1.419799
# Garrett\16 Little Wing.mp3                            ...    -2.039929
# Garrett\10 Air.mp3                                    ...     0.968112
# Garrett\04 He's a Pirate (Pirates of the Car 1.mp3    ...     0.243751
# Garrett\11 Thunderstruck.mp3                          ...    -0.370490
# Garrett\12 New Day.mp3                                ...     0.539471
# Garrett\01 Smooth Criminal 1.mp3                      ...     0.486619
# Garrett\05 Summertime 1.mp3                           ...     0.964380
# Garrett\02 Who Wants to Live Forever_ 1.mp3           ...    -0.894893
# Garrett\09 O Mio Babbino Caro 1.mp3                   ...    -0.702550
# Garrett\03 Clair de Lune 1.mp3                        ...    -2.190572
# Garrett\14 Rock Prelude.mp3                           ...     0.561216
# RageAgainstTheMachine\09 Township Rebellion.mp3       ...    -0.112510
# RageAgainstTheMachine\07 Wake Up.mp3                  ...     0.532134
# RageAgainstTheMachine\08 Fistful of Steel.mp3         ...     0.712606
# RageAgainstTheMachine\03 Take the Power Back.mp3      ...    -0.249797
# RageAgainstTheMachine\04 Settle for Nothing.mp3       ...     0.065938
# RageAgainstTheMachine\01 Bombtrack.mp3                ...     0.015087
# RageAgainstTheMachine\06 Know Your Enemy.mp3          ...     0.043923
# RageAgainstTheMachine\02 Killing In the Name.mp3      ...     0.117948
# RageAgainstTheMachine\10 Freedom.mp3                  ...     0.447330
# RageAgainstTheMachine\05 Bullet In the Head.mp3       ...     0.849700
# BeastieBoys\04 No Sleep Till Brooklyn.mp3             ...    -0.512267
# BeastieBoys\15 Fight for Your Right.mp3               ...    -0.377283
# BeastieBoys\03 Ch-Check It Out.mp3                    ...    -0.588881
# BeastieBoys\09 Shake Your Rump.mp3                    ...     1.871839
# BeastieBoys\06 Pass the Mic.mp3                       ...     1.404242
# BeastieBoys\10 Intergalactic.mp3                      ...     0.224699
# BeastieBoys\07 An Open Letter to NYC.mp3              ...     0.940183
# BeastieBoys\08 Root Down.mp3                          ...     1.779890
# BeastieBoys\12 Body Movin' (Fatboy Slim Remix).mp3    ...     0.869653
# BeastieBoys\05 Hey Ladies.mp3                         ...    -0.144487
# BeastieBoys\11 Sure Shot.mp3                          ...     0.748142
# BeastieBoys\01 So What'cha Want.mp3                   ...     0.136682
# Adele\12 Lovesong.mp3                                 ...     1.429404
# Adele\17 Rolling In The Deep.mp3                      ...     0.354947
# Adele\02 I'll Be Waiting.mp3                          ...    -0.617365
# Adele\13 Chasing Pavements.mp3                        ...     0.223836
# Adele\06 If It Hadn't Been For Love.mp3               ...    -1.412519
# Adele\11 One And Only.mp3                             ...    -0.815554
# Adele\04 Turning Tables.mp3                           ...    -2.022388
# Adele\08 Take It All.mp3                              ...    -2.074538
# Adele\15 Make You Feel My Love.mp3                    ...    -0.973704
# Adele\14 I Can't Make You Love Me.mp3                 ...    -1.073018
# Adele\16 Someone Like You.mp3                         ...    -2.125585
# Adele\05 Set Fire To The Rain.mp3                     ...    -1.075119
# Adele\09 Rumour Has It.mp3                            ...     0.653108
# Adele\01 Hometown Glory.mp3                           ...    -1.391123
# Adele\03 Don't You Remember.mp3                       ...    -1.288164
#
#                                                       power2    power3  \
# LanaDelRey\03 Blue Jeans (Remastered).mp3           1.627317  0.230091
# LanaDelRey\05 Diet Mountain Dew.mp3                -0.084565 -1.572489
# LanaDelRey\06 National Anthem.mp3                   0.883077  1.499469
# LanaDelRey\08 Radio.mp3                             0.913255  0.063046
# LanaDelRey\11 Summertime Sadness.mp3                1.156974  0.556218
# LanaDelRey\02 Off to the Races.mp3                 -0.081726  0.305810
# LanaDelRey\07 Dark Paradise.mp3                     0.805547  0.483749
# LanaDelRey\04 Video Games (Remastered).mp3          1.712758  0.128445
# LanaDelRey\01 Born to Die.mp3                       1.441617  0.272686
# LanaDelRey\10 Million Dollar Man.mp3                2.271447  0.530838
# LanaDelRey\12 This Is What Makes Us Girls.mp3       0.513009  1.091726
# LanaDelRey\09 Carmen.mp3                            0.493188  0.484739
# Garrett\16 Little Wing.mp3                         -1.362984 -1.859356
# Garrett\10 Air.mp3                                  0.783842 -0.839139
# Garrett\04 He's a Pirate (Pirates of the Car 1.mp3  0.055299  0.380381
# Garrett\11 Thunderstruck.mp3                       -0.886624 -0.026003
# Garrett\12 New Day.mp3                              0.459387 -0.494555
# Garrett\01 Smooth Criminal 1.mp3                   -1.153103 -1.783900
# Garrett\05 Summertime 1.mp3                         0.614350 -0.813599
# Garrett\02 Who Wants to Live Forever_ 1.mp3         0.031078  1.534595
# Garrett\09 O Mio Babbino Caro 1.mp3                 0.575184 -0.155730
# Garrett\03 Clair de Lune 1.mp3                      0.915538  0.814278
# Garrett\14 Rock Prelude.mp3                        -1.233174 -1.936699
# RageAgainstTheMachine\09 Township Rebellion.mp3     0
# BeastieBoys\12 Body Movin' (Fatboy Slim Remix).mp3  0.605193
# BeastieBoys\05 Hey Ladies.mp3                       0.031144
# BeastieBoys\11 Sure Shot.mp3                        0.315807
# BeastieBoys\01 So What'cha Want.mp3                -0.226148
# Adele\12 Lovesong.mp3                              -0.729013
# Adele\17 Rolling In The Deep.mp3                   -0.883734
# Adele\02 I'll Be Waiting.mp3                       -0.854365
# Adele\13 Chasing Pavements.mp3                     -0.295766
# Adele\06 If It Hadn't Been For Love.mp3            -0.537021
# Adele\11 One And Only.mp3                           0.270724
# Adele\04 Turning Tables.mp3                         0.295994
# Adele\08 Take It All.mp3                           -0.974029
# Adele\15 Make You Feel My Love.mp3                 -1.100602
# Adele\14 I Can't Make You Love Me.mp3              -1.606272
# Adele\16 Someone Like You.mp3                      -0.305187
# Adele\05 Set Fire To The Rain.mp3                  -0.973227
# Adele\09 Rumour Has It.mp3                          0.108565
# Adele\01 Hometown Glory.mp3                        -1.400626
# Adele\03 Don't You Remember.mp3                    -1.493994
#
# [60 rows x 42 columns]

# %% [markdown]
# ##### Ausgabe skaliertes test-Dataframe

# %%
display(testDF)
# Out:
#                                                     amp1mean   amp1std  \
# LanaDelRey\03 Blue Jeans (Remastered).mp3           0.320020  0.920985
# LanaDelRey\05 Diet Mountain Dew.mp3                 0.447328  1.207412
# LanaDelRey\06 National Anthem.mp3                   0.171603  1.538753
# LanaDelRey\08 Radio.mp3                            -0.073406  1.582302
# LanaDelRey\11 Summertime Sadness.mp3                0.382331  1.009525
# LanaDelRey\02 Off to the Races.mp3                  0.188770  1.559303
# LanaDelRey\07 Dark Paradise.mp3                     0.098468  0.935667
# LanaDelRey\04 Video Games (Remastered).mp3          0.579549  0.284196
# LanaDelRey\01 Born to Die.mp3                       0.642972  0.913491
# LanaDelRey\10 Million Dollar Man.mp3                0.587348  0.968326
# LanaDelRey\12 This Is What Makes Us Girls.mp3       0.214687  0.444791
# LanaDelRey\09 Carmen.mp3                            0.367610  0.434087
# Garrett\16 Little Wing.mp3                          0.258087 -0.847904
# Garrett\10 Air.mp3                                  0.255381 -0.337366
# Garrett\04 He's a Pirate (Pirates of the Car 1.mp3  0.284992  0.558023
# Garrett\11 Thunderstruck.mp3                        0.330053  0.301879
# Garrett\12 New Day.mp3                              0.294196 -1.050382
# Garrett\01 Smooth Criminal 1.mp3                    0.292577 -0.071971
# Garrett\05 Summertime 1.mp3                         0.269077 -0.800805
# Garrett\02 Who Wants to Live Forever_ 1.mp3         0.264295 -0.504885
# Garrett\09 O Mio Babbino Caro 1.mp3                 0.274450 -1.381066
# Garrett\03 Clair de Lune 1.mp3                      0.268810 -2.107634
# Garrett\14 Rock Prelude.mp3                         0.314847 -0.151351
# RageAgainstTheMachine\09 Township Rebellion.mp3     0.260050 -1.004473
# RageAgainstTheMachine\07 Wake Up.mp3                0.245552 -0.725009
# RageAgainstTheMachine\08 Fistful of Steel.mp3       0.285851 -1.226760
# RageAgainstTheMachine\03 Take the Power Back.mp3    0.266170 -0.366519
# RageAgainstTheMachine\04 Settle for Nothing.mp3     0.283728 -0.743333
# RageAgainstTheMachine\01 Bombtrack.mp3              0.236561 -0.182976
# RageAgainstTheMachine\06 Know Your Enemy.mp3        0.267036 -0.931203
# RageAgainstTheMachine\02 Killing In the Name.mp3    0.236482 -0.387350
# RageAgainstTheMachine\10 Freedom.mp3                0.255916 -0.625574
# RageAgainstTheMachine\05 Bullet In the Head.mp3     0.266659 -0.233206
# BeastieBoys\04 No Sleep Till Brooklyn.mp3           0.328602 -0.285898
# BeastieBoys\15 Fight for Your Right.mp3             0.400925  0.924032
# BeastieBoys\03 Ch-Check It Out.mp3                  0.210036  0.752937
# BeastieBoys\09 Shake Your Rump.mp3                 -4.740276  0.777126
# BeastieBoys\06 Pass the Mic.mp3                    -0.179711  1.798866
# BeastieBoys\10 Intergalactic.mp3                   -0.255674  2.115692
# BeastieBoys\07 An Open Letter to NYC.mp3            0.088721  1.021381
# BeastieBoys\08 Root Down.mp3                       -1.025384  0.879558
# BeastieBoys\12 Body Movin' (Fatboy Slim Remix).mp
# RageAgainstTheMachine\10 Freedom.mp3                 0.255916 -0.186042
# RageAgainstTheMachine\05 Bullet In the Head.mp3      0.266659 -0.079688
# BeastieBoys\04 No Sleep Till Brooklyn.mp3            0.328602  0.123629
# BeastieBoys\15 Fight for Your Right.mp3              0.400925  0.901843
# BeastieBoys\03 Ch-Check It Out.mp3                   0.210036  1.039786
# BeastieBoys\09 Shake Your Rump.mp3                  -4.740276  1.038778
# BeastieBoys\06 Pass the Mic.mp3                     -0.179711  1.995874
# BeastieBoys\10 Intergalactic.mp3                    -0.255674  2.505824
# BeastieBoys\07 An Open Letter to NYC.mp3             0.088721  1.460860
# BeastieBoys\08 Root Down.mp3                        -1.025384  1.043835
# BeastieBoys\12 Body Movin' (Fatboy Slim Remix).mp3  -0.146077  0.692015
# BeastieBoys\05 Hey Ladies.mp3                       -5.301103  0.551505
# BeastieBoys\11 Sure Shot.mp3                        -1.940092  1.770334
# BeastieBoys\01 So What'cha Want.mp3                 -0.265246  1.947229
# Adele\12 Lovesong.mp3                                0.239909 -0.514402
# Adele\17 Rolling In The Deep.mp3                     0.268936 -0.365015
# Adele\02 I'll Be Waiting.mp3                         0.145020 -0.656110
# Adele\13 Chasing Pavements.mp3                       0.045250 -0.376996
# Adele\06 If It Hadn't Been For Love.mp3              0.260732 -1.143041
# Adele\11 One And Only.mp3                            0.156957 -0.387927
# Adele\04 Turning Tables.mp3                          0.218772 -1.191381
# Adele\08 Take It All.mp3                             0.239054 -1.505298
# Adele\15 Make You Feel My Love.mp3                   0.265300 -1.378035
# Adele\14 I Can't Make You Love Me.mp3                0.249672 -1.655685
# Adele\16 Someone Like You.mp3                        0.253299 -1.337395
# Adele\05 Set Fire To The Rain.mp3                    0.152172 -0.689508
# Adele\09 Rumour Has It.mp3                           0.260407 -0.990253
# Adele\01 Hometown Glory.mp3                          0.253236 -1.225450
# Adele\03 Don't You Remember.mp3                      0.178511 -0.637845
#
#                                                       ...       power1  \
# LanaDelRey\03 Blue Jeans (Remastered).mp3             ...    -0.706898
# LanaDelRey\05 Diet Mountain Dew.mp3                   ...     1.583899
# LanaDelRey\06 National Anthem.mp3                     ...     1.040935
# LanaDelRey\08 Radio.mp3                               ...     0.669138
# LanaDelRey\11 Summertime Sadness.mp3                  ...     0.002133
# LanaDelRey\02 Off to the Races.mp3                    ...    -0.139224
# LanaDelRey\07 Dark Paradise.mp3                       ...     0.627960
# LanaDelRey\04 Video Games (Remastered).mp3            ...     1.164972
# LanaDelRey\01 Born to Die.mp3                         ...     0.192192
# LanaDelRey\10 Million Dollar Man.mp3                  ...    -0.586340
# LanaDelRey\12 This Is What Makes Us Girls.mp3         ...     0.581357
# LanaDelRey\09 Carmen.mp3                              ...     0.912359
# Garrett\16 Little Wing.mp3                            ...    -1.910749
# Garrett\10 Air.mp3                                    ...     0.864681
# Garrett\04 He's a Pirate (Pirates of the Car 1.mp3    ...     0.235071
# Garrett\11 Thunderstruck.mp3                          ...     0.176563
# Garrett\12 New Day.mp3                                ...    -0.539295
# Garrett\01 Smooth Criminal 1.mp3                      ...     0.512286
# Garrett\05 Summertime 1.mp3                           ...     0.234525
# Garrett\02 Who Wants to Live Forever_ 1.mp3           ...    -0.071268
# Garrett\09 O Mio Babbino Caro 1.mp3                   ...    -0.820154
# Garrett\03 Clair de Lune 1.mp3                        ...    -1.246546
# Garrett\14 Rock Prelude.mp3                           ...     0.881117
# RageAgainstTheMachine\09 Township Rebellion.mp3       ...     0.689911
# RageAgainstTheMachine\07 Wake Up.mp3                  ...     0.190617
# RageAgainstTheMachine\08 Fistful of Steel.mp3         ...     0.912495
# RageAgainstTheMachine\03 Take the Power Back.mp3      ...    -0.302990
# RageAgainstTheMachine\04 Settle for Nothing.mp3       ...    -1.041269
# RageAgainstTheMachine\01 Bombtrack.mp3                ...    -0.505216
# RageAgainstTheMachine\06 Know Your Enemy.mp3          ...     0.762986
# RageAgainstTheMachine\02 Killing In the Name.mp3      ...    -0.015863
# RageAgainstTheMachine\10 Freedom.mp3                  ...     1.599556
# RageAgainstTheMachine\05 Bullet In the Head.mp3       ...     0.143112
# BeastieBoys\04 No Sleep Till Brooklyn.mp3             ...    -0.827800
# BeastieBoys\15 Fight for Your Right.mp3               ...    -0.634687
# BeastieBoys\03 Ch-Check It Out.mp3                    ...    -0.368347
# BeastieBoys\09 Shake Your Rump.mp3                    ...     0.966033
# BeastieBoys\06 Pass the Mic.mp3                       ...     0.915280
# BeastieBoys\10 Intergalactic.mp3                      ...     0.956387
# BeastieBoys\07 An Open Letter to NYC.mp3              ...     1.318507
# BeastieBoys\08 Root Down.mp3                          ...     1.743116
# BeastieBoys\12 Body Movin' (Fatboy Slim Remix).mp3    ...     0.999960
# BeastieBoys\05 Hey Ladies.mp3                         ...    -0.169511
# BeastieBoys\11 Sure Shot.mp3                          ...     1.131044
# BeastieBoys\01 So What'cha Want.mp3                   ...     0.240851
# Adele\12 Lovesong.mp3                                 ...     1.172918
# Adele\17 Rolling In The Deep.mp3                      ...    -0.569516
# Adele\02 I'll Be Waiting.mp3                          ...    -1.027344
# Adele\13 Chasing Pavements.mp3                        ...    -0.047901
# Adele\06 If It Hadn't Been For Love.mp3               ...    -0.771409
# Adele\11 One And Only.mp3                             ...    -0.489685
# Adele\04 Turning Tables.mp3                           ...    -2.493969
# Adele\08 Take It All.mp3                              ...    -2.323060
# Adele\15 Make You Feel My Love.mp3                    ...    -0.052484
# Adele\14 I Can't Make You Love Me.mp3                 ...    -2.220037
# Adele\16 Someone Like You.mp3                         ...    -0.144036
# Adele\05 Set Fire To The Rain.mp3                     ...    -1.735470
# Adele\09 Rumour Has It.mp3                            ...     0.849692
# Adele\01 Hometown Glory.mp3                           ...    -1.240606
# Adele\03 Don't You Remember.mp3                       ...    -1.269979
#
#                                                       power2    power3  \
# LanaDelRey\03 Blue Jeans (Remastered).mp3           1.274752  0.504791
# LanaDelRey\05 Diet Mountain Dew.mp3                 0.109847 -0.831188
# LanaDelRey\06 National Anthem.mp3                   1.235297  0.786493
# LanaDelRey\08 Radio.mp3                             0.481110 -0.039016
# LanaDelRey\11 Summertime Sadness.mp3                1.180321  0.584842
# LanaDelRey\02 Off to the Races.mp3                 -0.137015 -0.085787
# LanaDelRey\07 Dark Paradise.mp3                     0.732797  0.844640
# LanaDelRey\04 Video Games (Remastered).mp3          1.340406  0.359644
# LanaDelRey\01 Born to Die.mp3                       1.465864  0.232769
# LanaDelRey\10 Million Dollar Man.mp3                2.102986  0.322762
# LanaDelRey\12 This Is What Makes Us Girls.mp3       0
# LanaDelRey\09 Carmen.mp3                           -1.446671
# Garrett\16 Little Wing.mp3                          1.785738
# Garrett\10 Air.mp3                                 -1.411115
# Garrett\04 He's a Pirate (Pirates of the Car 1.mp3 -0.640648
# Garrett\11 Thunderstruck.mp3                        0.580399
# Garrett\12 New Day.mp3                             -0.875176
# Garrett\01 Smooth Criminal 1.mp3                    0.279956
# Garrett\05 Summertime 1.mp3                         0.697522
# Garrett\02 Who Wants to Live Forever_ 1.mp3         0.912359
# Garrett\09 O Mio Babbino Caro 1.mp3                 0.815577
# Garrett\03 Clair de Lune 1.mp3                     -1.564674
# Garrett\14 Rock Prelude.mp3                         1.387213
# RageAgainstTheMachine\09 Township Rebellion.mp3     0.642018
# RageAgainstTheMachine\07 Wake Up.mp3                0.663401
# RageAgainstTheMachine\08 Fistful of Steel.mp3       0.808779
# RageAgainstTheMachine\03 Take the Power Back.mp3    0.725850
# RageAgainstTheMachine\04 Settle for Nothing.mp3     0.561742
# RageAgainstTheMachine\01 Bombtrack.mp3              0.533752
# RageAgainstTheMachine\06 Know Your Enemy.mp3        0.773853
# RageAgainstTheMachine\02 Killing In the Name.mp3    1.973801
# RageAgainstTheMachine\10 Freedom.mp3                1.457499
# RageAgainstTheMachine\05 Bullet In the Head.mp3     1.452720
# BeastieBoys\04 No Sleep Till Brooklyn.mp3           2.026102
# BeastieBoys\15 Fight for Your Right.mp3             1.877309
# BeastieBoys\03 Ch-Check It Out.mp3                  1.497407
# BeastieBoys\09 Shake Your Rump.mp3                 -0.273038
# BeastieBoys\06 Pass the Mic.mp3                    -0.765770
# BeastieBoys\10 Intergalactic.mp3                    1.556165
# BeastieBoys\07 An Open Letter to NYC.mp3            1.261674
# BeastieBoys\08 Root Down.mp3                       -0.351007
# BeastieBoys\12 Body Movin' (Fatboy Slim Remix).mp3  0.556479
# BeastieBoys\05 Hey Ladies.mp3                      -0.179499
# BeastieBoys\11 Sure Shot.mp3                        0.287434
# BeastieBoys\01 So What'cha Want.mp3                -0.423650
# Adele\12 Lovesong.mp3                              -0.084650
# Adele\17 Rolling In The Deep.mp3                   -0.279278
# Adele\02 I'll Be Waiting.mp3                       -0.859493
# Adele\13 Chasing Pavements.mp3                     -0.269759
# Adele\06 If It Hadn't Been For Love.mp3            -1.153937
# Adele\11 One And Only.mp3                          -0.678078
# Adele\04 Turning Tables.mp3                        -0.792582
# Adele\08 Take It All.mp3                           -0.732031
# Adele\15 Make You Feel My Love.mp3                 -0.978522
# Adele\14 I Can't Make You Love Me.mp3              -1.197159
# Adele\16 Someone Like You.mp3                      -1.374472
# Adele\05 Set Fire To The Rain.mp3                  -0.780901
# Adele\09 Rumour Has It.mp3                         -0.804083
# Adele\01 Hometown Glory.mp3                        -1.077562
# Adele\03 Don't You Remember.mp3                    -1.512189
#
# [60 rows x 42 columns]

# %% [markdown]
# #### Aufgabe 3
# Zur Berechnung der Distanz jeder ersten Teilsequenz zu jeder zweiten Teilsequenz iterieren wir mit einer verschachtelten for-Schleife über das train-Dataframe und das test-Dataframe. Innerhalb der inneren Schleife wird, je nach übergebenem Distanzmaß, die Distanz in ein Dictionary gespeichert, mit den Musiktiteln als Key und der Distanz als Value. Wurde für eine Teilsequenz aus dem train-Dataframe über alle Teilsequenzen des test-Dataframe iteriert, wird das Dictionary nach aufsteigenden Distanzen sortiert und die so entstandene Liste als Value in das finale Dictionary zum passenden Titel der gegebenen ersten Teilsequenz gespeichert.<br>
# Wenn beide Schleifen komplett durchgelaufen sind, wird das Dictionary zurückgegeben, das alle Musiktitel aus dem train-Dataframe als Keys und alle Distanzen dieser Teilsequenzen zu den Teilsequenzen des test-Dataframes als Values enthält.

# %%
def distance(similarity, trainDataframe, testDataframe):
    allDistDict = {}
    for index, row in trainDataframe.iterrows():
        distDict = {}
        for index2, row2 in testDataframe.iterrows():
            if similarity == 'dist_euclid':
                distDict[index2] = spatial.distance.euclidean(row, row2)
            if similarity == 'dist_correlation':
                distDict[index2] = spatial.distance.correlation(row, row2)

        distList = sorted(distDict.items(), key=lambda t: t[1], reverse=False)
        allDistDict[index] = distList
    return allDistDict

# %% [markdown]
# Wir lassen uns die Distanzen sowohl mit dem euklidischen Distanzmaß berechnen, als auch mit dem Distanzmaß, dem die Pearson-Korrelation zugrunde liegt.

# %%
allDistancesDictEuclid = distance('dist_euclid', trainDF, testDF)
allDistancesDictCorrelation = distance('dist_correlation', trainDF, testDF)

# %% [markdown]
# ##### Distanzen berechnet mit euklidischem Distanzmaß

# %%
display(allDistancesDictEuclid)
# Out:
# {'Adele\\01 Hometown Glory.mp3': [('Adele\\01 Hometown Glory.mp3',
#    3.247608310720818),
#   ("Adele\\06 If It Hadn't Been For Love.mp3", 3.5806638204298045),
#   ("Adele\\14 I Can't Make You Love Me.mp3", 4.007842587536962),
#   ('Adele\\08 Take It All.mp3', 4.4320503257141475),
#   ('Adele\\16 Someone Like You.mp3', 4.831663209037793),
#   ('Adele\\15 Make You Feel My Love.mp3', 5.648196506946329),
#   ('Adele\\04 Turning Tables.mp3', 5.980012831493088),
#   ('Adele\\17 Rolling In The Deep.mp3', 6.145504550818936),
#   ('Adele\\05 Set Fire To The Rain.mp3', 6.241469414020442),
#   ("Adele\\02 I'll Be Waiting.mp3", 6.325773214208027),
#   ("Adele\\03 Don't You Remember.mp3", 6.382353900256193),
#   ('Adele\\11 One And Only.mp3', 6.389095205873206),
#   ('Adele\\12 Lovesong.mp3', 6.396312895894329),
#   ('Adele\\09 Rumour Has It.mp3', 6.731746349543011),
#   ('Adele\\13 Chasing Pavements.mp3', 7.65080838104612),
#   ('RageAgainstTheMachine\\01 Bombtrack.mp3', 7.7082328897418035),
#   ('Garrett\\05 Summertime 1.mp3', 7.715226085423948),
#   ('LanaDelRey\\12 This Is What Makes Us Girls.mp3', 8.075839509805542),
#   ('RageAgainstTheMachine\\07 Wake Up.mp3', 8.58359225443228),
#   ('LanaDelRey\\04 Video Games (Remastered).mp3', 8.600571327428018),
#   ('LanaDelRey\\03 Blue Jeans (Remastered).mp3', 8.662427922303173),
#   ('RageAgainstTheMachine\\05 Bullet In the Head.mp3', 8.717507486193739),
#   ('Garrett\\12 New Day.mp3', 8.82549570944942),
#   ("Garrett\\04 He's a Pirate (Pirates of the Car 1.mp3", 8.94999016966627),
#   ('LanaDelRey\\11 Summertime Sadness.mp3', 8.976260611866103),
#   ("BeastieBoys\\12 Body Movin' (Fatboy Slim Remix).mp3", 8.976966131497399),
#   ('LanaDelRey\\01 Born to Die.mp3', 9.067731630666854),
#   ('LanaDelRey\\10 Million Dollar Man.mp3', 9.21284944293481),
#   ('Garrett\\02 Who Wants to Live Forever_ 1.mp3', 9.337459344503047),
#   ('LanaDelRey\\07 Dark Paradise.mp3', 9.4092655314153),
#   ('Garrett\\11 Thunderstruck.mp3', 9.511533218118739),
#   ('Garrett\\03 Clair de Lune 1.mp3', 9.601442203333036),
#   ('Garrett\\09 O Mio Babbino Caro 1.mp3', 9.61097039033815),
#   ('RageAgainstTheMachine\\09 Township Rebellion.mp3', 9.888736528550588),
#   ('RageAgainstTheMachine\\06 Know Your Enemy.mp3',
#   ("Adele\\14 I Can't Make You Love Me.mp3", 1.0214890743072536),
#   ('LanaDelRey\\09 Carmen.mp3', 1.0228737566653074),
#   ('Adele\\12 Lovesong.mp3', 1.031172907109147),
#   ('Adele\\15 Make You Feel My Love.mp3', 1.0323763604365204),
#   ('Adele\\08 Take It All.mp3', 1.0336979982686527),
#   ('RageAgainstTheMachine\\01 Bombtrack.mp3', 1.0457527653324479),
#   ('BeastieBoys\\15 Fight for Your Right.mp3', 1.0492196852742945),
#   ('BeastieBoys\\09 Shake Your Rump.mp3', 1.0750529310544876),
#   ('BeastieBoys\\10 Intergalactic.mp3', 1.0897557008979901),
#   ('Adele\\01 Hometown Glory.mp3', 1.0914519612330311),
#   ('BeastieBoys\\08 Root Down.mp3', 1.1059077374444968),
#   ('BeastieBoys\\11 Sure Shot.mp3', 1.1408880489824489),
#   ('LanaDelRey\\07 Dark Paradise.mp3', 1.1600743478816293),
#   ('BeastieBoys\\06 Pass the Mic.mp3', 1.1806830213871042),
#   ('LanaDelRey\\02 Off to the Races.mp3', 1.2490539798545848),
#   ('Adele\\04 Turning Tables.mp3', 1.249692611401045),
#   ('Adele\\13 Chasing Pavements.mp3', 1.2522850050508185),
#   ("BeastieBoys\\01 So What'cha Want.mp3", 1.321867053608595),
#   ('Adele\\11 One And Only.mp3', 1.332562322512716),
#   ('LanaDelRey\\06 National Anthem.mp3', 1.3344334648359357),
#   ("BeastieBoys\\12 Body Movin' (Fatboy Slim Remix).mp3", 1.3461352915014788),
#   ("Garrett\\04 He's a Pirate (Pirates of the Car 1.mp3", 1.3551686310555056),
#   ('LanaDelRey\\05 Diet Mountain Dew.mp3', 1.3611554116103994),
#   ('LanaDelRey\\04 Video Games (Remastered).mp3', 1.3690517489136533),
#   ('LanaDelRey\\08 Radio.mp3', 1.383387027841455),
#   ('Adele\\05 Set Fire To The Rain.mp3', 1.4149832117855972),
#   ('LanaDelRey\\11 Summertime Sadness.mp3', 1.4783861257931266),
#   ("Adele\\02 I'll Be Waiting.mp3", 1.4786709173543788),
#   ('LanaDelRey\\03 Blue Jeans (Remastered).mp3', 1.4822959380705354),
#   ('LanaDelRey\\10 Million Dollar Man.mp3', 1.4850190461472486),
#   ("Adele\\03 Don't You Remember.mp3", 1.4905431175626505),
#   ('Adele\\17 Rolling In The Deep.mp3', 1.5036077805964925),
#   ('LanaDelRey\\01 Born to Die.mp3', 1.5882404567406545)]}

# %% [markdown]
# #### Aufgabe 4 & 5
# Bei der Berechnung des mittleren Rangs iterieren wir über das Dictionary, das wir bei der Berechnung der Distanzen erstellt haben. Da die Distanzwerte aufsteigend sortiert sind, lässt sich durch Iterieren über die Values des Dictionary und einem Stringvergleich des Keys mit dem jeweiligen Label des Distanzwerts der Rang jeder Teilsequenz herausfinden. Alle Ränge werden aufsummiert und anschließend durch die Anzahl Musiktitel geteilt.

# %%
def meanRank(allDistDict):
    rankSum = 0
    for key, value in allDistDict.items():
        rank = 1
        for element in value:
            if element[0] == key:
                rankSum += rank
            else:
                rank += 1

    meanRank = rankSum / len(allDistDict)
    return meanRank


euclidMeanRank = meanRank(allDistancesDictEuclid)
correlationMeanRank = meanRank(allDistancesDictCorrelation)

print("mittlerer Rang auf Basis der euklidischen Distanz:", euclidMeanRank)
print("mittlerer Rang auf Basis der Pearson-Korrelation:", correlationMeanRank)
# Out:
# mittlerer Rang auf Basis der euklidischen Distanz: 2.5166666666666666
# mittlerer Rang auf Basis der Pearson-Korrelation: 2.65

# %% [markdown]
# ## Merkmalsauswahl mit dem genetischen Algorithmus
# In diesem Abschnitt soll unter Anwendung eines selbst zu implementierenden genetischen Algorithmus eine Untermenge wichtiger Merkmale aus den insgesamt 42 angelegten Merkmalen berechnet werden.
# Als Vorlage kann hierfür die Implementierung für die [Lösung des TSP Problems](https://www.hdm-stuttgart.de/~maucher/Python/FunktionenAlgorithmen/html/genAlgTSP.html) herangezogen werden. Anzupassen sind dann jedoch mindestens die Fitness-Funktion, die Kreuzungs- und die Mutationsfunktion. Die Fitness soll so wie im vorigen Teilabschnitt mit dem mittleren Rang berechnet werden. Die Populationsgröße, die Anzahl der auszuwählenden Merkmale und die Anzahl der Iterationen sollen als Parameter einstellbar sein.
#
# Der Fitnesswert des besten Individuums in der Population soll in jeder Iteration gespeichert werden. Der Verlauf dieses besten Fitness-Wertes über den Fortlauf der Iterationen soll graphisch ausgegeben werden.
#
# Ein Pandas Frame, der nur die berechneten wichtigsten Merkmale aus _FeatureFileTrainingAllList1.csv_ enthält soll angelegt und in die csv Datei _subFeaturesTrain1.csv_ geschrieben werden.
#
# **Aufgaben:**
# 1. Implementieren Sie die die Merkmalsauswahl mit dem genetischen Algorithmus entsprechend der o.g. Beschreibung
# 2. Beschreiben Sie kurz das Konzept ihrer Kreuzungs- und Mutationsfunktion.
# 3. Bestimmen Sie eine möglichst kleine Merkmalsuntermenge mit einem möglichst guten mittleren Rang? Geben Sie sowohl die gefundenen wichtigsten Merkmale als auch den zugehörigen mittleren Rang an.
# 4. Um wieviel verschlechtert sich der Mittlere Rang, wenn nur die 10 wichtigsten Merkmale benutzt werden?

# %% [markdown]
# #### Genetischer Algorithmus für die Music Feature Selection

# %% [markdown]
# #### Initialisierung einer Population
# Auf Grundlage der festgelegten Populationsgröße ($popsize$) und Größe der Merkmalsuntermenge ($featurecount$) wird ein zweidimenionales Numpy-Array mit $popsize$ Individuen/Chromosomen und $featurecount$ unterschiedlichen Merkmalen zufällig erstellt.

# %%
def initPopulation(popsize, featurecount):
    population = np.zeros((popsize, featurecount))
    for i in range(populationSize):
        population[i, 0:featureCount] = np.random.permutation(random.sample(range(len(FeatNames)), featurecount))
    return population

# %% [markdown]
# #### Fitness-Funktion
# Die Fitness-Funktion berechnet für jedes Individuum der Population den Fitnesswert, mithilfe der bereits implementierten Funktionen *distances* und *meanRank* auf Basis der euklidischen Distanz. Für die Berechnung muss das  train-Dataframe und das test-Dataframe für jedes Individuum neu erstellt werden. Diese Dataframes werden dann an die *distances*-Funktion übergeben. Zurückgegeben wird ein Dictionary, das alle Fitnesswerte als Keys enthält, mit einer Liste der zugehörigen Merkmale als Values.

# %%
def calculateFitness(population):
    fitnessDict = {}
    for chromosome in population:
        featureList = []
        for featureIndex in chromosome:
            featureList.append(FeatNames[int(featureIndex)])
        subTrainDataFrame = pd.DataFrame(index=trainDF.index, columns=featureList, data=trainDF[featureList])
        subTestDataFrame = pd.DataFrame(index=testDF.index, columns=featureList, data=testDF[featureList])

        distances = distance('dist_euclid', subTrainDataFrame, subTestDataFrame)
        fitnessValue = meanRank(distances)
        fitnessDict[fitnessValue] = chromosome
    return fitnessDict

# %% [markdown]
# #### Selektierung
# Die Selektierungs-Funktion basiert auf der Selektierungfunktion der Lösung des Travelling-Salesman-Problems. Es werden zwei Eltern ausgewählt, wobei die Sekeltion von Indivduen mit gutem Fitnesswert wahrscheinlicher ist, als die Selektion von Individuen mit schlechtem Fitnesswert.

# %%
def selection(populationFitnessDict):
    allfitnessValues = populationFitnessDict.keys()
    inverseFitnessDict = {}
    allfitnessValues = 1/np.array(sorted(allfitnessValues))
    for key in populationFitnessDict.keys():
        inverseFitnessDict[1/key] = key

    allfitnessValuesSum = np.array(allfitnessValues).sum()
    rn1 = allfitnessValuesSum * np.random.rand()
    found1 = False
    found2 = False
    index = 1
    while not found1:
        if rn1 < allfitnessValues[:index].sum(axis=0):
            found1 = index
        else:
            index += 1
    found1 = found1 - 1
    equal = True
    while equal:
        rn2 = allfitnessValuesSum * np.random.rand()
        found2 = False
        index = 1
        while not found2:
            if rn2 < allfitnessValues[:index].sum(axis=0):
                found2 = index
            else:
                index += 1
        found2 = found2 - 1
        if found2 != found1:
            equal = False
    parent1 = populationFitnessDict[inverseFitnessDict[allfitnessValues[found1]]]
    parent2 = populationFitnessDict[inverseFitnessDict[allfitnessValues[found2]]]
    return parent1, parent2

# %% [markdown]
# #### Mutationsfunktion
# Der Mutationsfunktion werden die, durch die Kreuzung entstanden Kinderindividuen übergeben, sowie ein Wahrscheinlichkeitswert *mutationProb*. Für jedes der beiden Kinderindividuen wird ein Zufallswert zwischen 1 und 100 bestimmt. Ist dieser kleiner, als die Wahrscheinlichkeit, die durch mutationProb festgelegt wurde, findet eine Mutation statt.
# Bei der Mutation wird ein zufälliges Merkmal des Individuums ausgewählt und durch ein zufälliges anderes Merkmal ersetzt, das das Individuum noch nicht enthält.

# %%
def mutation(mutationProb, child1, child2):
    childList = np.array([child1, child2])
    for child in childList:
        mutrn = random.randint(0, 100)
        if mutrn < mutationProb:
            childList = np.delete(childList, 0, 0)
            reducedFeatNames = []
            for idx, element in enumerate(FeatNames):
                if idx not in child:
                    reducedFeatNames.append(element)
            reducedFeatNames = np.array(reducedFeatNames)
            randomReplaceIndex = random.randint(0, len(child) - 1)
            randomFeatNameIndex = random.randint(0, len(reducedFeatNames) - 1)
            child[randomReplaceIndex] = FeatNames.index(reducedFeatNames[randomFeatNameIndex])
            childList = np.vstack((childList, child))
    return childList

# %% [markdown]
# #### Kreuzungsfunktion
# Mithilfe der bereits implemetierten Funktion *selection* werden zwei Individuen zur Kreuzung ausgewählt. Damit die Laufzeit verbessert wird, werden die Merkmale so sortiert, dass weitestgehend vermieden wird, dass bei der Kreuzung doppelte Merkmale in den entstehenden Individuen auftreten.<br>
# Anschließend werden die Elternindividuen an einer zufälligen Grenze geteilt, die zwischen $\frac{1}{4}$ und $\frac{3}{4}$ der Gesamtlänge des Individuums liegt. Es werden Kopf-A mit dem Ende-B und Kopf-B mit Ende-A zusammengefügt. Wenn beide entstandenen Individuen noch *featurecount*-Anzahl Merkmale enthalten, war die Kreuzung erfolgreich. Wenn nicht, wird die Selektion und die Kreuzung wiederholt.<br>
# Bei einer erfolgreichen Kreuzung wird anschließend die Mutationsfunktion aufgerufen. Dann werden für die Merkmale der Individuen Untermengen der train- und test-Dataframes erstellt und für diese die Fitnesswerte berechnet. Sind die Fitnesswerte besser als der schlechteste Fitnesswert der Population, werden die Kinderindividuen zurückgegeben.

# %%
def crossing(populationFitnessDict, mutationProb, featurecount):
    while True:
        parents = selection(populationFitnessDict)
        parent1 = sorted(parents[0])
        parent2 = sorted(parents[1])
        crossBoarder = random.randint(round(featurecount / 4), 3*round(featurecount / 4))
        parent1A = parent1[:int(crossBoarder)]
        parent1B = parent1[int(crossBoarder):]
        parent2B = parent2[:int(crossBoarder)]
        parent2A = parent2[int(crossBoarder):]
        child1 = np.append(parent1A, parent2A)
        child2 = np.append(parent1B, parent2B)
        if len(set(child1)) == featurecount and len(set(child2)) == featurecount:
            childList = mutation(mutationProb, child1, child2)
            for index, child in enumerate(childList):
                featureList = []
                for featureIndex in child:
                    featureList.append(FeatNames[int(featureIndex)])
                subTrainDataFrame = pd.DataFrame(index=trainDF.index, columns=featureList, data=trainDF[featureList])
                subTestDataFrame = pd.DataFrame(index=testDF.index, columns=featureList, data=testDF[featureList])

                distances = distance('dist_euclid', subTrainDataFrame, subTestDataFrame)
                fitnessValue = meanRank(distances)
                if fitnessValue > sorted(populationFitnessDict.keys())[-1]:
                    childList = np.delete(childList, 0, 0)
            return childList

# %% [markdown]
# #### Aufgabe 4 - Speichern
# Es wird das train-Dataframe auf Basis der Merkmale des Individuums mit dem besten Fitnesswert der Population gebildet und in einer csv-Datei gespeichert.

# %%
def saveFeatures(population):
    populationFitnessDict = calculateFitness(population)
    bestFitnessValue = sorted(populationFitnessDict.keys())[0]
    featureList = []
    for featureIndex in populationFitnessDict[bestFitnessValue]:
        featureList.append(FeatNames[int(featureIndex)])
    subTrainDataFrame = pd.DataFrame(index=trainDF.index, columns=featureList, data=trainDF[featureList])
    subTrainDataFrame.to_csv("subFeaturesTrain1.csv")

# %% [markdown]
# #### Ablauf des Algorithmus
# Übergabeparameter:
# > initiale Population,<br>
# Anzahl Merkmale pro Individuum,<br>
# Anzahl Iterationen,<br>
# Wahrscheinlichkeit für Mutationen<br>
#
# In einer Schleife werden nacheinander die Fitnessfunktion und dann die Kreuzungsfunktion aufgerufen. Werden von der Kreuzungsfunktion Kinder zurückgegeben, werden dieser der Population hinzugefügt und die Individuen mit den schlechtesten Fitnesswerten aus der Population entfernt. Nach allen Iterationen wird das beste Individuum mit zugehörigem Fitnesswert ausgegeben und die Population zurückgegeben.

# %%
def startGeneticAlgorithm(initialPopulation, featurecount, iterations, mutationProbability):
    f = FloatProgress(min=0, max=iterations, description="Progress")
    display(f)

    population = initialPopulation
    i = 0
    while i < iterations:
        f.value += 1
        populationFitnessDict = calculateFitness(population)
        childList = crossing(populationFitnessDict, mutationProbability, featurecount)
        j = 0
        while j < len(childList):
            worstChromosome = populationFitnessDict[sorted(populationFitnessDict.keys())[-1]]
            del populationFitnessDict[sorted(populationFitnessDict.keys())[-1]]
            worstIndex = np.where(np.all(population == worstChromosome, axis=1))
            population = np.delete(population, worstIndex[0][0], axis=0)
            population = np.vstack([population, childList[j]])
            j += 1
        i += 1
    populationFitnessDict = calculateFitness(population)
    bestFitnessValue = sorted(populationFitnessDict.keys())[0]
    featureList = []
    for featureIndex in populationFitnessDict[bestFitnessValue]:
        featureList.append(FeatNames[int(featureIndex)])
    print("best chromosome:", bestFitnessValue, featureList)
    return population

# %% [markdown]
# #### Music Feature Selection

# %% [markdown]
# **Populationsgröße:** 20 -
# **Merkmalsanzahl:** 20 -
# **Iterationen:** 100 -
# **Mutationswahrscheinlichkeit:** 5%

# %%
populationSize = 20
featureCount = 20
iterations = 100
mutationProbability = 5  # in %

population = initPopulation(populationSize, featureCount)
population = startGeneticAlgorithm(population, featureCount, iterations, mutationProbability)
saveFeatures(population)
# Out:
# FloatProgress(value=0.0, description='Progress')
# best chromosome: 1.8833333333333333 ['amp1mean', 'amp1skew', 'amp10mean', 'amp10std', 'amp10skew', 'amp10kurt', 'amp10dstd', 'amp10dskew', 'amp100mean', 'amp100skew', 'amp100dkurt', 'amp1000std', 'amp1000dskew', 'power1', 'power3', 'power4', 'power5', 'power6', 'power7', 'power9']

# %% [markdown]
# **Populationsgröße:** 20 -
# **Merkmalsanzahl:** 15 -
# **Iterationen:** 100 -
# **Mutationswahrscheinlichkeit:** 5%

# %%
populationSize = 20
featureCount = 15
iterations = 100
mutationProbability = 5  # in %

population = initPopulation(populationSize, featureCount)
population = startGeneticAlgorithm(population, featureCount, iterations, mutationProbability)
# Out:
# FloatProgress(value=0.0, description='Progress')
# best chromosome: 2.1666666666666665 ['power10', 'amp1mean', 'amp1std', 'amp1kurt', 'amp1dkurt', 'amp10std', 'amp10skew', 'amp10kurt', 'amp100mean', 'amp1000mean', 'amp1000std', 'power1', 'power2', 'power7', 'power8']
# array([[10., 11., 24., 25., 26., 32., 33., 38., 39., 41.,  0.,  5.,  6.,
#         13., 15.],
#        [32., 33., 38., 39., 41.,  0.,  5.,  6., 10., 11., 13., 15., 24.,
#         25., 26.],
#        [25., 26., 32., 33., 38., 39., 41.,  0.,  5.,  6., 10., 11., 13.,
#         15., 24.],
#        [26., 32., 33., 38., 39., 41.,  0.,  5.,  6., 10., 11., 13., 15.,
#         24., 25.],
#        [15., 24., 25., 26., 32., 33., 38., 39., 41.,  0.,  5.,  6., 10.,
#         11., 13.],
#        [26., 32., 33., 38., 39., 41.,  0.,  5.,  6., 10., 11., 13., 15.,
#         24., 25.],
#        [ 0.,  1.,  3.,  7.,  9., 10., 11., 24., 25., 16., 32., 33., 38.,
#         39., 41.],
#        [41.,  0.,  5.,  6., 10., 11., 13., 15., 24., 25., 26., 32., 33.,
#         38., 39.],
#        [25., 32., 33., 38., 39., 41.,  0.,  1.,  3.,  7.,  9., 10., 11.,
#         16., 24.],
#        [ 0.,  1.,  3.,  7.,  9., 10., 11., 16., 24., 25., 32., 33., 38.,
#         39., 41.],
#        [ 0.,  5.,  6., 10., 11., 13., 15., 24., 25., 26., 32., 33., 38.,
#         39., 41.],
#        [ 0.,  5.,  6., 10., 11., 13., 15., 24., 25., 26., 32., 33., 38.,
#         39., 41.],
#        [39., 41.,  0.,  1.,  3.,  7.,  9., 10., 11., 16., 24., 25., 32.,
#         33., 38.],
#        [ 0.,  1.,  3.,  7.,  9., 10., 11., 16., 24., 25., 32., 33., 38.,
#         39., 41.],
#        [ 0.,  1.,  3.,  7.,  9., 10., 11., 16., 24., 25., 32., 33., 38.,
#         39., 41.],
#        [ 0.,  5.,  6., 10., 11., 13., 15., 24., 25., 26., 32., 33., 38.,
#         39., 41.],
#        [ 0.,  5.,  6., 10., 11., 13., 15., 24., 25., 26., 32., 33., 38.,
#         39., 41.],
#        [ 0.,  5.,  6., 10., 11., 13., 15., 24., 25., 26., 32., 33., 38.,
#         39., 41.],
#        [ 0.,  5.,  6., 10., 11., 13., 15., 24., 25., 26., 32., 33., 38.,
#         39., 41.],
#        [41.,  0.,  1.,  3.,  7.,  9., 10., 11., 16., 24., 25., 32., 33.,
#         38., 39.]])

# %% [markdown]
# **Populationsgröße:** 50 -
# **Merkmalsanzahl:** 20 -
# **Iterationen:** 100 -
# **Mutationswahrscheinlichkeit:** 5%

# %%
populationSize = 50
featureCount = 20
iterations = 100
mutationProbability = 5  # in %

population = initPopulation(populationSize, featureCount)
population = startGeneticAlgorithm(population, featureCount, iterations, mutationProbability)
# Out:
# FloatProgress(value=0.0, description='Progress')
# best chromosome: 1.8 ['amp1mean', 'amp1std', 'amp1skew', 'amp10std', 'amp10skew', 'amp10kurt', 'amp10dstd', 'amp10dskew', 'amp100mean', 'amp100std', 'amp100skew', 'amp100kurt', 'amp1000dstd', 'amp1000dskew', 'power2', 'power4', 'power6', 'power7', 'power8', 'power9']
# array([[14.,  9., 19., 13., 15., 31., 38.,  2., 37.,  8., 32., 29.,  6.,
#         41.,  1., 16., 17., 18., 34., 35.],
#        [30., 33., 35., 37., 38., 39., 40.,  0.,  7., 10., 11., 14., 16.,
#         17., 18., 21., 23., 24., 25., 28.],
#        [ 1.,  2.,  6.,  7.,  8.,  9., 10., 13., 15., 16., 17., 25., 27.,
#         30., 33., 35., 37., 38., 39., 40.],
#        [ 1.,  2.,  6.,  8.,  9., 13., 14., 15., 16., 17., 18., 19., 29.,
#         30., 33., 35., 37., 38., 39., 40.],
#        [13., 15., 18., 21., 22., 23., 25., 29., 35., 36., 37., 39., 41.,
#          0.,  7., 10., 11., 14., 16., 17.],
#          6.,  8.,  9., 13., 14., 15., 16.],
#        [16., 17., 18., 19., 27., 29., 30., 34., 35., 38., 39., 41.,  1.,
#          2.,  6.,  8.,  9., 13., 14., 15.],
#        [ 1.,  2.,  6.,  7.,  8.,  9., 10., 14., 16., 17., 18., 19., 29.,
#         30., 33., 35., 37., 25., 39., 40.]])

# %% [markdown]
# **Populationsgröße:** 20 -
# **Merkmalsanzahl:** 20 -
# **Iterationen:** 500 -
# **Mutationswahrscheinlichkeit:** 5%

# %%
populationSize = 20
featureCount = 30
iterations = 100
mutationProbability = 5  # in %

population = initPopulation(populationSize, featureCount)
population = startGeneticAlgorithm(population, featureCount, iterations, mutationProbability)
# Out:
# FloatProgress(value=0.0, description='Progress')
# best chromosome: 1.9166666666666667 ['amp100dkurt', 'amp1000mean', 'amp1000skew', 'amp1000dmean', 'amp1000dstd', 'amp1000dskew', 'amp1000dkurt', 'power2', 'power3', 'power4', 'power5', 'power7', 'power8', 'power9', 'power10', 'amp1mean', 'amp1std', 'amp1skew', 'amp1kurt', 'amp1dstd', 'amp1dskew', 'amp10mean', 'amp10skew', 'amp10dskew', 'amp10dkurt', 'amp100mean', 'amp100std', 'amp100kurt', 'amp100dmean', 'amp100dskew']

# %% [markdown]
# #### Aufgabe 4
# **Populationsgröße:** 20 -
# **Merkmalsanzahl:** 10 -
# **Iterationen:** 100 -
# **Mutationswahrscheinlichkeit:** 5%

# %%
populationSize = 20
featureCount = 10
iterations = 100
mutationProbability = 5  # in %

population = initPopulation(populationSize, featureCount)
population = startGeneticAlgorithm(population, featureCount, iterations, mutationProbability)
# Out:
# FloatProgress(value=0.0, description='Progress')

# %% [markdown]
# ## Clustering und automatische Playlistgenerierung
# Implementieren Sie ein hierarchisches Clustering aller Subsequenzen in _subFeaturesTrain1.csv_. Diese _.csv_-Datei enthält nur die im vorigen Schritt ermittelten wichtigsten Merkmale. Das hierarchische Clustering ist in einem Dendrogram der Art wie in der unten gegebenen Abbildung zu visualisieren.
#
# Die gefundenen Cluster sind mit den zugehörigen Musiktiteln in der Konsole auszugeben.
#
# **Aufgaben:**
#
# 1. Optimieren Sie die Parameter
#
#     1. metric (Ähnlichkeitsmaß)
#     2. linkage method
#     3. Clusteranzahl
#
# 2. Für welche Parameterkonstellation erlangen Sie das für Sie subjektiv betrachtet günstigste Ergebnis?
# 3. Überlegen Sie sich Ansätze um diese Art der Musikgruppierung zu verbessern?
#
# ![Abbildung Music Clustering](https://www.hdm-stuttgart.de/~maucher/ipnotebooks/DataMining//Bilder/playlistCluster.png "Music Clustering")

# %%
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

def clustering():
    data = pd.read_csv("subFeaturesTrain1.csv")
    data = data.set_index("Unnamed: 0")
    dist = spatial.distance.pdist(data)
    Z = linkage(dist, 'average', 'correlation')
    plt.figure(figsize=(15, 10), dpi=80)
    plt.title('Hierarchical Clustering Dendrogram')
    plt.xlabel("distance")
    plt.ylabel('music titles')
    dendrogram(
        Z,
        leaf_font_size=8,
        labels=data.index,
        orientation='right'
    )
    plt.show()

# %%
clustering()
